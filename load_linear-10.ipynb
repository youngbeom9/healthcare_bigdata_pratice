# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\302-28\Downloads\fall_summary_cleaned.csv",encoding='CP949')

fall = df['fall']
caution = df['caution']
mon = df['mon']

plt.rc('figure',figsize=(10,8))
plt.rc('font',family='Malgun Gothic')
plt.title('주의와 낙상의 상관관계')
plt.xlabel('주의')
plt.ylabel('낙상')
plt.scatter(caution,fall)
plt.show()

# %%
df.head()
# Out:
#   deviceId    mon  caution  fall
# 0      #01  23/01     35.0   1.0
# 1      #01  23/07    130.0   6.0
# 2      #01  23/08     94.0   3.0
# 3      #01  23/11     48.0   1.0
# 4      #01  23/12     54.0   1.0

# %%
import seaborn as sns
sns.regplot(x=caution,y=fall,data=df)
# Out:
# <Axes: xlabel='caution', ylabel='fall'>
